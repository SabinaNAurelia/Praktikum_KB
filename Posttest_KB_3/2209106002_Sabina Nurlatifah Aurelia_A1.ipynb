# %% [markdown]
# <h1>Nama : Sabina Nurlatifah Aurelia</h1>
# <h1>NIM  : 2209106002</h1>
# <h1>Kelas: Informatika A1 2022</h1>

# %% [markdown]
# <h4>Visualisasi Data Posttest 3</h4>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np

matplotlib.style.use('ggplot') # grafik menggunakan gaya ggplot

# %% [markdown]
# <h4>Import library yang dibutuhkan</h4>

# %%
df= pd.read_csv('tornados.csv')
df.head()
# Out:
#     om    yr  mo  dy        date      time               tz  \
# 0  192  1950  10   1  1950-10-01  21:00:00  America/Chicago
# 1  193  1950  10   9  1950-10-09  02:15:00  America/Chicago
# 2  195  1950  11  20  1950-11-20  02:20:00  America/Chicago
# 3  196  1950  11  20  1950-11-20  04:00:00  America/Chicago
# 4  197  1950  11  20  1950-11-20  07:30:00  America/Chicago
#
#            datetime_utc  st  stf  ...   elon   len  wid  ns  sn   f1  f2  f3  \
# 0  1950-10-02T03:00:00Z  OK   40  ... -102.3  15.8   10   1   1   25   0   0
# 1  1950-10-09T08:15:00Z  NC   37  ...    0.0   2.0  880   1   1   47   0   0
# 2  1950-11-20T08:20:00Z  KY   21  ...    0.0   0.1   10   1   1  177   0   0
# 3  1950-11-20T10:00:00Z  KY   21  ...    0.0   0.1   10   1   1  209   0   0
# 4  1950-11-20T13:30:00Z  MS   28  ...    0.0   2.0   37   1   1  101   0   0
#
#    f4     fc
# 0   0  False
# 1   0  False
# 2   0  False
# 3   0  False
# 4   0  False
#
# [5 rows x 27 columns]

# %% [markdown]
# <h4>Menampilkan 5 data teratas dari dataset</h4>

# %%
#Total korban cidera berdasarkan tahun menggunakan diagram batang
injuries_sorted_by_year = df.groupby('yr')['inj'].sum().sort_values(ascending=True)
injuries_sorted_by_year[:73].plot(kind='bar', color=sns.color_palette('Paired'), figsize=(20, 10))
plt.xlabel('Year')
plt.ylabel('Injuried Person')
plt.title ('Banyaknya korban Cedera ')
plt.show()

# %% [markdown]
# <h4>Dari diagram diatas menunjukkan jumlah korban terluka berdasarkan tahunnya. 2018 merupakan angka terkecil dan angka yang terbesar ada pada tahun 1974</h4>

# %%
# Histogram 
plt.hist(df['mag'], range=(1, 3))
plt.xlabel('Magnitude')
plt.ylabel('Total Injuried Person')
plt.title('Histogram of Magnitude')
plt.show()

# %% [markdown]
# <h4>Dari histogram diatas skala magnitudo jumlah orang yang terluka ada pada skala 1.00 dengan jumlah 2000+ orang terluka</h4>

# %%
#scatterplot
sns.scatterplot(
    data=df,
    x='inj',
    y='fat',
    hue='yr',
)
plt.xlim(5, 100)
plt.ylim(5, 100)
# Out:
# E:\KB3\newkb\.aureli\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\KB3\newkb\.aureli\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\KB3\newkb\.aureli\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# (5.0, 100.0)

# %% [markdown]
# <h4>Angka korban jiwa tertinggi ada pada sekitar tahun 1995 dimana hingga 20+ orang meninggal dunia, lalu tertinggi kedua sekitar tahun 2010 dengan jumlah korban jiwa sekitar 20+ orang</h4>

# %%
yr_group= df.groupby('yr').sum()
yr_group.head()
yr_group.index
# Out:
# Index([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961,
#        1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#        1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022],
#       dtype='int64', name='yr')

# %% [markdown]
# <h4>Membuat kolom year menjadi index</h4>

# %%
#lineplot
sns.lineplot(data=yr_group.loc[:, 'mag':'fat'])
plt.xticks(np.arange(1950, 2020, 10).astype('str'))
# Out:
# E:\KB3\newkb\.aureli\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\KB3\newkb\.aureli\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\KB3\newkb\.aureli\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# E:\KB3\newkb\.aureli\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# <h4>Angka kematian mulai tinggi sekitar tahun 1950 dengan skala magnitudo yang tidak terlalu tinggi,  <br>tetapi banyak korban yang cidera</h4>

# %%
#pie chart
plt.pie(yr_group['inj'].sort_values(),
        labels= yr_group['inj'].sort_values().index,
        autopct= '%1.1f%%',
        startangle= 360)
# Out:
# ([<matplotlib.patches.Wedge at 0x1afad487e80>,
# ...
#  [Text(1.0999773656647287, 0.007056559025752303, '2018'),
#   Text(1.099710262970278, 0.025245544514670565, '2022'),
#   Text(1.0989569499873917, 0.04789177460075916, '2016'),
#   Text(1.0975494589995236, 0.07338382008217535, '2004'),
#   Text(1.0953216332353692, 0.10134357289243062, '2009'),
#   Text(1.0918606307691092, 0.13356782163561476, '2017'),
#   Text(1.0867589181129285, 0.170161846199486, '1951'),
#   Text(1.0803177349519257, 0.20715595948063129, '1958'),
#   Text(1.0725231878484724, 0.2443235795566007, '1986'),
#   Text(1.0634321788198298, 0.28126855681094176, '2019'),
#   Text(1.0530586898171588, 0.31791098722845207, '2005'),
#   Text(1.0414116119765557, 0.35420594918831, '1963'),
#   Text(1.0283378468966264, 0.3905397196701131, '1962'),
#   Text(1.0129076962599242, 0.42897319130385475, '2007'),
#   Text(0.9946831972481432, 0.4696864242366512, '2014'),
#   Text(0.9741321633435323, 0.5109466981394928, '1950'),
# ...

# %% [markdown]
# <h4>Rata-rata persentase korban cidera bencana tornado tertinggi ada pada tahun 1974 dengan total 7.0% dari jumlah penduduk America/Chicago</h4>

# %%
year_injuries_corr = df.loc [:, 'stf':'fat'].corr()
year_injuries_corr
# Out:
#           stf       mag       inj       fat
# stf  1.000000 -0.016824 -0.012648 -0.010924
# mag -0.016824  1.000000  0.220756  0.195581
# inj -0.012648  0.220756  1.000000  0.761659
# fat -0.010924  0.195581  0.761659  1.000000

# %% [markdown]
# <h4>Menampilkan data antar korelasi dari <br>
# stf = state FIPS (Federal Information Processing Standards) <br>
# mag = skala magnitudo<br>
# inj = korban cidera <br>
# fat = korban jiwa</h4>

# %%
#heatmap
sns.heatmap(data=year_injuries_corr, cmap='Reds', annot=True, center=0)
plt.show()

# %% [markdown]
# <h4>stf = state FIPS (Federal Information Processing Standarts) <br>
# mag = Skala Magnitudo<br>
# inj = Korban Cidera <br>
# fat = Korban Jiwa <br>
# Korelasi stf lebih rendah dibandingkan dengan jumlah korban jiwa yang terjadi selama bencana tornado 1950-2022</h4>
